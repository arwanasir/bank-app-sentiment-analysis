# %%
# Sentiment and Thematic Analysis
import sys
import os
sys.path.append('../src')

import pandas as pd
from sentiment import perform_sentiment_analysis
from themes import extract_themes

# %%
# Load data
df = pd.read_csv('../data/processed/cleaned_reviews.csv')

# %%
# Sentiment Analysis
print("😊 Performing sentiment analysis...")
df = perform_sentiment_analysis(df)

# %%
# Thematic Analysis
print("🎯 Extracting themes...")
df = extract_themes(df)

# %%
# Save results
df.to_csv('../data/processed/final_analyzed_reviews.csv', index=False

# %%
# Show insights
print("\n📈 KEY INSIGHTS:")
print(f"• Total reviews analyzed: {len(df)}")
print(f"• Sentiment distribution: {df['sentiment_label'].value_counts().to_dict()}")
print(f"• Top themes: {df['theme'].value_counts().head(5).to_dict()}")

print("✅ Task 2 completed!")
